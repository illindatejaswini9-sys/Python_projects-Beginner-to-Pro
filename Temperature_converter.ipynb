# %%
#Temperature Converter
#Define Conversion functions

def celsius_to_fahreinheit(celsius):
 return (celsius*9/5) +32
def celsius_to_kelvin(celsius):
 return celsius + 273.15
def fahreinheit_to_celsius(fahreinheit):
 return (fahreinheit-32) * 5/9
def fahreinheit_to_kelvin(fahreinheit):
 return (fahreinheit - 32)*5/9 +273.15
def kelvin_to_celsius(kelvin):
 return kelvin-273.15
def kelvin_to_fahreinheit(kelvin):
 return (kelvin - 273.15) * 9/5 +32

#step2:Display the menu
def Show_menu():
  print("\nTemperature converter menu:")
  print("1.Celsius to Fahrenheit&Kelvin")
  print("2.Fahrenheit to celsius&Kelvin")
  print("3.kelvin to Celsius&Fahreinheit")
  print("4.Exit")

#step 3: Main Program loop
while True:
  Show_menu()
  choice = input("Enter your choice(1/2/3/4): ")

  if choice == '1':
    celsius = float(input("Enter temperature in celsius: "))
    print(f"Fahreinheit:{celsius_to_fahreinheit(celsius):.2f}")
    #above .2f gives decimals upto 2
    print(f"Kelvin:{celsius_kelvin(celsius):.2f}")

  elif choice == '2':
    fahreinheit = float(input("Enter temperature in fahreinheit: "))
    print(f"Celsius:{fahreinheit_to_celsius(fahreinheit):.3f}")
    print(f"Kelvin:{fahreinheit_to_kelvin(fahreinheit):.3f}")

  elif choice == '3':
    kelvin = float(input("Enter temperature in kelvin: "))
    print(f"Celsius:{kelvin_to_celsius(kelvin):.3f}")
    print(f"fahreinheit:{kelvin_to_fahreinheit(kelvin):.3f}")

  elif choice == '4':
    print("Exiting the programm!")
    break

  else:
    print("Invalid Option")
# Out:
# Temperature converter menu:
# 1.Celsius to Fahrenheit&Kelvin
# 2.Fahrenheit to celsius&Kelvin
# 3.kelvin to Celsius&Fahreinheit
# 4.Exit
# Enter your choice(1/2/3/4): 3
# Enter temperature in kelvin: 273.15
# Celsius:0.000
# fahreinheit:32.000
# Temperature converter menu:
# 1.Celsius to Fahrenheit&Kelvin
# 2.Fahrenheit to celsius&Kelvin
# 3.kelvin to Celsius&Fahreinheit
# 4.Exit
