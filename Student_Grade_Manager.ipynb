# %%
#Student Grade Manager
# Get Student scores
student_scores = input("Enter student scores using comma: ")
scores = [int(score) for score in student_scores.split(",") ]

#Assign grades
grades = [ "A" if score>90 else
           "B" if score>80 else
           "C" if score>70 else
           "D" if score>=60 else
           "F" for score in scores
]
#Filter passing and failing students
passing_students = [score for score in scores if score>=60]
failing_students = [score for score in scores if score<60]
for i,(score,grade) in enumerate(zip(scores,grades),start = 1):
 print(f"Student{i},Score={score},Grade = {grade}")

print("\n--passing and failing students--")
print(f"Passing Students:{passing_students}")
print(f"Failing Students:{failing_students}")
# Out:
# Enter student scores using comma: 60,56,88,76,98,96
# Student1,Score=60,Grade = D
# Student2,Score=56,Grade = F
# Student3,Score=88,Grade = B
# Student4,Score=76,Grade = C
# Student5,Score=98,Grade = A
# Student6,Score=96,Grade = A
#
# --passing and failing students--
# Passing Students:[60, 88, 76, 98, 96]
# Failing Students:[56]
