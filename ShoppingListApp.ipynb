# %%
#SHOPPING LIST APP
#1.Initialize an empty Shopping list
Shopping_List =[]

#2. Define the main menu
def show_menu():
  print("\n---Shopping List Menu---")
  print("1. View the Shopping list")
  print("2. Add an item")
  print("3. Remove an item")
  print("4. Clear list")
  print("5. Exit")

#3.Main program loop
while True:
  show_menu()
  choice = input("Enter your choice (1-5): ")

  if choice == "1":
    print("\n---Shopping List---")
    if not Shopping_List:
        print("Your shopping list is empty")
    else:
        for index, item in enumerate(Shopping_List):
            print(f"{index+1}. {item}")

  elif choice == "2":
    item = input("Enter an item to add:")
    Shopping_List.append(item)
    print(f"{item} is added")

  elif choice == "3":
    item = input ("Enter an item to remove:")
    if item in Shopping_List:
      Shopping_List.remove(item)
      print(f"{item} is removed")
    else:
      print(f"{item} is not in the list")

  elif choice == "4":
    Shopping_List.clear()
    print("Shopping list is cleared")

  elif choice == "5":
    print("Exiting the program")
    break
# Out:
# ---Shopping List Menu---
# 1. View the Shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear list
# 5. Exit
# Enter your choice (1-5): 2
# Enter an item to add:Milk
# Milk is added
#
# ---Shopping List Menu---
# 1. View the Shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear list
# 5. Exit
# Enter your choice (1-5): 2
# Enter an item to add:Bread
# Bread is added
#
# ---Shopping List Menu---
# 1. View the Shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear list
# 5. Exit
# Enter your choice (1-5): 2
# Enter an item to add:Butter
# Butter is added
#
# ---Shopping List Menu---
# 1. View the Shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear list
# 5. Exit
# Enter your choice (1-5): 1
#
# ---Shopping List---
# 1. Milk
# 2. Bread
# 3. Butter
#
# ---Shopping List Menu---
# 1. View the Shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear list
# 5. Exit
# Enter your choice (1-5): 5
# Exiting the program
