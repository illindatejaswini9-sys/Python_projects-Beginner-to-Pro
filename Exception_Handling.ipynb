# %% [markdown]
# <a href="https://colab.research.google.com/github/illindatejaswini9-sys/Python_projects-Beginner-to-Pro/blob/main/Exception_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num = int(input("Enter a Number:"))
  result = 10/num
  print("Result:",result)
except ZeroDivisionError:
  print("error:Division by zero is not allowed")
except ValueError:
  print("Invalid Input ,enter a valid number:")
# Out:
# Enter a Number:0
# error:Division by zero is not allowed

# %%
try:
  #code that might raise an exception
except exceptiontype:
  #code to handle exception
else:
  #code to execute if ther's no exception
finally:
  #always execute even if an exception occurs

# %%
try:
  num = int(input("enter your number to be divided"))
  result = 10/num
except ZeroDivisionError:
  print("Error:cannot be divided by zero")
else:
  print("No exception,the reslt is :",result)
finally:
  print("Block finally excecuted")
# Out:
# Block finally excecuted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2710726809.py in <cell line: 0>()
#       1 try:
# ----> 2   num = int(input("enter your number to be divided"))
#       3   result = 10/num
#       4 except ZeroDivisionError:
#       5   print("Error:cannot be divided by zero")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
#Multiple error handling
try:
  num = int(input("enter your number to be divided"))
  result = 10/num
except (ZeroDivisionError, ValueError):
  print("Error:cannot be divided by zero or Invalid Input")
# Out:
# enter your number to be dividedok
# Error:cannot be divided by zero or Invalid Input

# %%
#Raising custom Exceptions
def withdraw(amount):
 if amount<0:
  raise ValueError("Invalid withdrawl amount, cannot be negative")
 else:
  print(f"you have withdrawn ${amount}")

try:
  withdraw(-50)
except ValueError as e:
  print(e)
# Out:
# Invalid withdrawl amount, cannot be negative

# %%
#safe Calculator
#step1:define calculator functions
def add(x,y):
  return x + y
def subtract(x,y):
  return x-y
def multiply (x,y):
  return x*y
def divide(x,y):
 if y ==0:
  raise ZeroDivisionError("Cannot divide by zero")
 return x/y

#step2: Display Menu
def Show_menu():
  print("\n--Safe Calculator Menu--")
  print("1.Add")
  print("2.Subtract")
  print("3.Multiply")
  print("4.Divide")
  print("5.Exit")

#step3 : Main Programm
while True:
  Show_menu()
  choice = input("Enter your choice(1-5)")
  if choice == "5":
   print("Exiting the calculator.GoodBye")
   break

  try:
    x = int(input("give the 1st number to be calculated: "))
    y = int(input("give the second number to be inputed: "))

    if choice == "1":
      result = add(x,y)
      print(f"Result: {x} + {y} = {result}")
    elif choice == "2":
      result = subtract(x,y)
      print(f"Result: {x} - {y} = {result}")
    elif choice == "3":
      result = multiply(x,y)
      print(f"Result: {x} * {y} = {result}")
    elif choice == "4":
      result = divide(x,y)
      print(f"Result: {x} / {y} = {result}")
    else:
      print("Invalid choice. Please enter a number between 1 and 5.")

  except ValueError:
    print("Invalid input. Please enter a valid number.")
  except ZeroDivisionError as e:
    print(f"Error: {e}")
  except Exception as e:
    print(f"An unexpected error occurred: {e}")
  finally:
    print("Thank you for using the Safe Calculator!... Restarting...")
# Out:
# --Safe Calculator Menu--
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# Enter your choice(1-5)1
# give the 1st number to be calculated: 5
# give the second number to be inputed: 6
# Result: 5 + 6 = 11
#
# --Safe Calculator Menu--
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3736385612.py in <cell line: 0>()
#      24 while True:
#      25   Show_menu()
# ---> 26   choice = input("Enter your choice(1-5)")
#      27   if choice == "5":
#      28    print("Exiting the calculator.GoodBye")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...
