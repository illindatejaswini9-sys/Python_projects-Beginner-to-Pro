# %%
#Ingredient checker

#step1: Define the reciper ingredients
recipe_ingredients = {"flour","sugar","butter","milk","oil"}

#ste2 : Get user input for available ingredients
user_input = input("Enter the ingredients you have(seperated by commas)")
user_ingredients = set(user_input.split(","))

#step3 :Compare Ingredients
missing_ingredients = recipe_ingredients - user_ingredients
extra_ingredients =  user_ingredients - recipe_ingredients

#step4 : Display Results
print("/n--Ingredients Check Result--")
if missing_ingredients :
  print(f"you are missing following ingredients:{','.join(missing_ingredients)}"
  )
else:
  print("you have all the ingredients needed")
if extra_ingredients:
  print(f"you have extra ingredients:{','.join(extra_ingredients)}")
# Out:
# Enter the ingredients you have(seperated by commas)flour,sugar,eggs
# you are missing following ingredients:milk,butter,oil
# you have extra ingredients:eggs
